# %%
import pandas as pd

# %%
sal_hitter = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HK/kbo_salary/salary_hitter.csv')
sal_pitcher = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/HK/kbo_salary/salary_pitcher.csv')

# %%
sal_hitter = sal_hitter.drop(labels='Unnamed: 0',axis=1)

# %%
sal_pitcher = sal_pitcher.drop(labels='Unnamed: 0',axis=1)

# %%
sal_hitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   선수명     100 non-null    object
#  1   salary  100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
sal_hitter.loc[sal_hitter['salary'].str.contains("만원")]
# Out:
#     선수명    salary
# 1   김도영   10000만원
# 2   최원준   22000만원
# 3   박찬호   30000만원
# 4   최형우  100000만원
# 5   김선빈   60000만원
# ..  ...       ...
# 95  이주형    6600만원
# 96  고영우    3000만원
# 97  김태진   11000만원
# 98  이용규   20000만원
# 99  김건희    3200만원
#
# [91 rows x 2 columns]

# %%
sal_hitter.shape
# Out:
# (100, 2)

# %%
sal_hitter_kr = sal_hitter.loc[sal_hitter['salary'].str.contains("만원")]

# %%
sal_hitter_kr.shape
# Out:
# (91, 2)

# %%
sal_hitter_kr = sal_hitter.loc[sal_hitter['salary'].str.contains("만원")]
sal_hitter_kr['salary'] = sal_hitter_kr['salary'].str.slice(0,-2)
sal_hitter_kr['salary'] = pd.to_numeric(sal_hitter_kr['salary'])
# Out:
# <ipython-input-61-7cfd6bb46e4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_hitter_kr['salary'] = sal_hitter_kr['salary'].str.slice(0,-2)
# <ipython-input-61-7cfd6bb46e4c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_hitter_kr['salary'] = pd.to_numeric(sal_hitter_kr['salary'])

# %%
sal_hitter_kr.to_csv('hitter_salary_kr2.csv',index=False)

# %%
sal_pitcher_kr = sal_pitcher.loc[sal_pitcher['salary'].str.contains("만원")]

# %%
sal_pitcher_kr.shape
# Out:
# (125, 2)

# %%
sal_pitcher_kr['salary'] = sal_pitcher_kr['salary'].str.slice(0,-2)
sal_pitcher_kr['salary'] = pd.to_numeric(sal_pitcher_kr['salary'])
# Out:
# <ipython-input-67-bc745ea932be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_pitcher_kr['salary'] = sal_pitcher_kr['salary'].str.slice(0,-2)
# <ipython-input-67-bc745ea932be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_pitcher_kr['salary'] = pd.to_numeric(sal_pitcher_kr['salary'])

# %%
sal_hitter_kr.head()
# Out:
#    선수명    salary
# 1  김도영   10000만원
# 2  최원준   22000만원
# 3  박찬호   30000만원
# 4  최형우  100000만원
# 5  김선빈   60000만원

# %%
sal_hitter_kr['salary'] = sal_hitter_kr['salary'].str.slice(0,-2)
sal_hitter_kr['salary'] = pd.to_numeric(sal_hitter_kr['salary'])
# Out:
# <ipython-input-49-7cfd6bb46e4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_hitter_kr['salary'] = sal_hitter_kr['salary'].str.slice(0,-2)
# <ipython-input-49-7cfd6bb46e4c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_hitter_kr['salary'] = pd.to_numeric(sal_hitter_kr['salary'])

# %%
sal_pitcher_kr['salary'] = sal_pitcher_kr['salary'].str.slice(0,-2)
sal_pitcher_kr['salary'] = pd.to_numeric(sal_pitcher_kr['salary'])
# Out:
# <ipython-input-50-bc745ea932be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_pitcher_kr['salary'] = sal_pitcher_kr['salary'].str.slice(0,-2)
# <ipython-input-50-bc745ea932be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_pitcher_kr['salary'] = pd.to_numeric(sal_pitcher_kr['salary'])

# %%
sal_hitter_kr.to_csv('hitter_salary_kr.csv',index=False)

# %%
sal_pitcher_kr.to_csv('pitcher_salary_kr2.csv',index=False)

# %%
sal_hitter_kr['선수명'].unique()
# Out:
# array(['김도영', '최원준', '박찬호', '최형우', '김선빈', '한준수', '이창진', '이우성', '나성범',
#        '강민호', '김지찬', '김영웅', '이성규', '구자욱', '박병호', '김헌곤', '이재현', '류지혁',
#        '이병헌', '문보경', '박해민', '신민재', '홍창기', '김현수', '구본혁', '박동원', '문성주',
#        '오지환', '강승호', '양석환', '정수빈', '김재환', '조수행', '양의지', '허경민', '전민재',
#        '이유찬', '최지훈', '박성한', '한유섬', '최정', '이지영', '오태곤', '고명준', '하재훈',
#        '추신수', '강백호', '황재균', '장성우', '문상철', '김상수', '김민혁', '배정대', '오재일',
#        '신본기', '안치홍', '노시환', '이도윤', '김태연', '채은성', '황영묵', '최재훈', '문현빈',
#        '최인호', '박승욱', '윤동희', '황성빈', '나승엽', '고승민', '정훈', '전준우', '최항', '손호영',
#        '서호철', '김휘집', '권희동', '김성욱', '김주원', '박민우', '김형준', '박건우', '손아섭',
#        '송성문', '최주환', '김혜성', '김재현', '이주형', '고영우', '김태진', '이용규', '김건희'],
#       dtype=object)

# %%
sal_pitcher_kr['선수명'].unique()
# Out:
# array(['박정우', '장재혁', '정해영', '양현종', '이형범', '곽도규', '이준영', '장현식', '윤영철',
#        '황동하', '전상현', '김사윤', '최지광', '원태인', '김태훈', '백정현', '이상민', '황동재',
#        '임창민', '김재윤', '이승현', '홍원표', '오승환', '최채흥', '성동현', '함덕주', '유영찬',
#        '이종준', '김유영', '김진성', '이상영', '우강훈', '손주영', '윤호솔', '정우영', '최원태',
#        '김택연', '박신지', '홍건희', '김강률', '최지강', '이병헌', '김도윤', '곽빈', '이영하',
#        '최준호', '박정수', '장지훈', '박시후', '노경은', '이기순', '문승원', '조병현', '박민호',
#        '한두솔', '오원석', '이로운', '김광현', '서진용', '송영진', '우규민', '박세진', '박영현',
#        '김민', '박시영', '김민수', '김영현', '엄상백', '이선우', '고영표', '육청명', '이상동',
#        '손동현', '남지민', '김서현', '김민우', '주현상', '이민우', '이충호', '류현진', '장민재',
#        '한승혁', '황준서', '장시환', '김범수', '김강현', '정현수', '정우준', '김상수', '김원중',
#        '박진', '한현희', '박진형', '김진욱', '진해수', '박세웅', '구승민', '최준용', '김민규',
#        '손주환', '김재열', '김영규', '한재승', '이용찬', '신민혁', '김시훈', '임정호', '이준호',
#        '이재학', '송명기', '최우석', '조상우', '김재웅', '하영민', '김성민', '김동욱', '주승우',
# ...

# %%
sal_hitter_kr.to_csv('hitter_salary_kr2.csv',index=False)
sal_pitcher_kr.to_csv('pitcher_salary_kr2.csv',index=False)

# %%
hitter = pd.read_csv('hitter_salary.csv')
hitter.shape
# Out:
# (249, 2)

# %%
pitcher= pd.read_csv('pitcher_salary.csv')
pitcher.shape
# Out:
# (249, 2)

# %%
sal_hitter_kr = hitter.loc[hitter['salary'].str.contains("만원")]
sal_hitter_kr['salary'] = sal_hitter_kr['salary'].str.slice(0,-2)
sal_hitter_kr['salary'] = pd.to_numeric(sal_hitter_kr['salary'])
sal_hitter_kr.shape
# Out:
# <ipython-input-82-99db59f12d70>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_hitter_kr['salary'] = sal_hitter_kr['salary'].str.slice(0,-2)
# <ipython-input-82-99db59f12d70>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_hitter_kr['salary'] = pd.to_numeric(sal_hitter_kr['salary'])
# (236, 2)

# %%
sal_hitter_kr.shape
# Out:
# (236, 2)

# %%
sal_pitcher_kr.to_csv('pitcher_salary_kr3.csv',index=False)

# %%
sal_pitcher_kr = pitcher.loc[pitcher['salary'].str.contains("만원")]
sal_pitcher_kr['salary'] = sal_pitcher_kr['salary'].str.slice(0,-2)
sal_pitcher_kr['salary'] = pd.to_numeric(sal_pitcher_kr['salary'])
sal_pitcher_kr.shape
# Out:
# <ipython-input-83-31f73b524bb3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_pitcher_kr['salary'] = sal_pitcher_kr['salary'].str.slice(0,-2)
# <ipython-input-83-31f73b524bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sal_pitcher_kr['salary'] = pd.to_numeric(sal_pitcher_kr['salary'])
# (219, 2)

# %%
sal_hitter_kr.to_csv('hitter_salary_kr3.csv',index=False)

# %%
pd.read_csv('hitter_salary_kr3.csv')
# Out:
#      선수명  salary
# 0    김규성    5500
# 1    한승택    6500
# 2    김도영   10000
# 3    한준수    5000
# 4    이우성   13000
# ..   ...     ...
# 231  김시앙    3600
# 232  김주형    4500
# 233  박성빈    3000
# 234  김웅빈    5000
# 235  임지열    7200
#
# [236 rows x 2 columns]

# %%
pd.read_csv('pitcher_salary_kr3.csv')
# Out:
#      선수명  salary
# 0    박정우    3800
# 1    장재혁    3000
# 2    정해영   20000
# 3    양현종   50000
# 4    이형범    7000
# ..   ...     ...
# 214  조영건    4000
# 215  박승주    4500
# 216  정찬헌   20000
# 217  오석주    4000
# 218  윤석원    4300
#
# [219 rows x 2 columns]
